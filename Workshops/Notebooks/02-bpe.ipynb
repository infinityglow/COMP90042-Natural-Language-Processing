# %% [markdown]
# Train BPE on a toy text example
#
# bpe algorithm: https://web.stanford.edu/~jurafsky/slp3/2.pdf (2.4.3)

# %%
import re, collections

# text = "The aims for this subject is for students to develop an understanding of the main algorithms used in naturallanguage processing, for use in a diverse range of applications including text classification, machine translation, and question answering. Topics to be covered include part-of-speech tagging, n-gram language modelling, syntactic parsing and deep learning. The programming language used is Python, see for more information on its use in the workshops, assignments and installation at home."
text = 'low '*5 +'lower '*2+'newest '*6 +'widest '*3
def get_vocab(text):
    vocab = collections.defaultdict(int)
    for word in text.strip().split():
        #note: we use the special token </w> (instead of underscore in the lecture) to denote the end of a word
        vocab[' '.join(list(word)) + ' </w>'] += 1
    return vocab


"""

This function iterates through all words in the vocabulary and count pair of tokens which are next to each other.

EXAMPLE:
    word = 'T h e <\w>'
    pairs of tokens in this word [('T', 'h'), ('h', 'e'), ('e', '<\w>')]
    
INPUT:
    vocab: Dict[str, int]  # The vocabulary, a counter for word frequency
    
OUTPUT:
    pairs: Dict[Tuple[str, str], int] # Word pairs, a counter for pair frequency

"""
def get_stats(vocab):
    pairs = collections.defaultdict(int)
    ###
    # Your answer BEGINS HERE
    ###
    for word, freq in vocab.items():
        char_list = word.split()
        for i in range(len(char_list)-1):
            pairs[(char_list[i], char_list[i+1])] += freq
    
    ###
    # Your answer ENDS HERE
    ###
    return pairs


"""
This function merges a given pair of tokens in all words in the vocabulary

EXAMPLE:
    word = 'T h e <\w>'
    pair = ('e', '<\w>')
    word_after_merge = 'T h e<\w>'
    
Input:
    pair: Tuple[str, str] # the pair of tokens need to be merged
    v_in: Dict[str, int]  # vocabulary before merge
    
Output:
    v_out: Dict[str, int] # vocabulary after merge
    
HINT:
    When merging pair ('h', 'e') for word 'Th e<\w>', the two tokens in this word 'Th' and 'e<\w>' shouldn't be merged.

"""
def merge_vocab(pair, v_in):
    v_out = {}
    ###
    # Your answer BEGINS HERE
    ###
    for word, freq in v_in.items():
        char_list = word.split()
        for i in range(len(char_list)-1):
            if char_list[i] == pair[0] and char_list[i+1] == pair[1]:
                merged_chars = ''.join(pair)
                char_list.insert(char_list.index(pair[0]), merged_chars)
                char_list.remove(pair[0]); char_list.remove(pair[1])
        word_ = ' '.join(char_list)
        v_out[word] = freq
    
    ###
    # Your answer ENDS HERE
    ###
    return v_out

def get_tokens(vocab):
    tokens = collections.defaultdict(int)
    for word, freq in vocab.items():
        word_tokens = word.split()
        for token in word_tokens:
            tokens[token] += freq
    return tokens


vocab = get_vocab(text)
print("Vocab =", vocab)
print('==========')
print('Tokens Before BPE')
tokens = get_tokens(vocab)
print('Tokens: {}'.format(tokens))
print('Number of tokens: {}'.format(len(tokens)))
print('==========')

#about 100 merges we start to see common words
num_merges = 100
for i in range(num_merges):
    pairs = get_stats(vocab)
    if not pairs:
        break
    best = max(pairs, key=pairs.get)
    new_token = ''.join(best)
    vocab = merge_vocab(best, vocab)
    print('Iter: {}'.format(i))
    print('Best pair: {}'.format(best))
    # add new token to the vocab
    tokens[new_token] = pairs[best]
    # deduct frequency for tokens have been merged
    tokens[best[0]] -= pairs[best]
    tokens[best[1]] -= pairs[best]
    print('Tokens: {}'.format(tokens))
    print('Number of tokens: {}'.format(len(tokens)))
    print('==========')
# Out:
# Vocab = defaultdict(<class 'int'>, {'l o w </w>': 5, 'l o w e r </w>': 2, 'n e w e s t </w>': 6, 'w i d e s t </w>': 3})
# ==========
# Tokens Before BPE
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -469, 'r': 2, 'n': 6, 's': -477, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 54
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -478, 'r': 2, 'n': 6, 's': -486, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 55
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -487, 'r': 2, 'n': 6, 's': -495, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 56
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -496, 'r': 2, 'n': 6, 's': -504, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 57
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -505, 'r': 2, 'n': 6, 's': -513, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 58
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -514, 'r': 2, 'n': 6, 's': -522, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 59
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -523, 'r': 2, 'n': 6, 's': -531, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 60
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -532, 'r': 2, 'n': 6, 's': -540, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 61
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -541, 'r': 2, 'n': 6, 's': -549, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 62
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -550, 'r': 2, 'n': 6, 's': -558, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 63
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -559, 'r': 2, 'n': 6, 's': -567, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 64
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -568, 'r': 2, 'n': 6, 's': -576, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 65
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -577, 'r': 2, 'n': 6, 's': -585, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 66
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -586, 'r': 2, 'n': 6, 's': -594, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 67
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -595, 'r': 2, 'n': 6, 's': -603, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 68
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -604, 'r': 2, 'n': 6, 's': -612, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 69
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -613, 'r': 2, 'n': 6, 's': -621, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 70
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -622, 'r': 2, 'n': 6, 's': -630, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 71
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -631, 'r': 2, 'n': 6, 's': -639, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 72
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -640, 'r': 2, 'n': 6, 's': -648, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 73
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -649, 'r': 2, 'n': 6, 's': -657, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 74
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -658, 'r': 2, 'n': 6, 's': -666, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 75
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -667, 'r': 2, 'n': 6, 's': -675, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 76
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -676, 'r': 2, 'n': 6, 's': -684, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 77
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -685, 'r': 2, 'n': 6, 's': -693, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 78
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -694, 'r': 2, 'n': 6, 's': -702, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 79
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -703, 'r': 2, 'n': 6, 's': -711, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 80
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -712, 'r': 2, 'n': 6, 's': -720, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 81
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -721, 'r': 2, 'n': 6, 's': -729, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 82
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -730, 'r': 2, 'n': 6, 's': -738, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 83
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -739, 'r': 2, 'n': 6, 's': -747, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 84
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -748, 'r': 2, 'n': 6, 's': -756, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 85
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -757, 'r': 2, 'n': 6, 's': -765, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 86
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -766, 'r': 2, 'n': 6, 's': -774, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 87
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -775, 'r': 2, 'n': 6, 's': -783, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 88
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -784, 'r': 2, 'n': 6, 's': -792, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 89
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -793, 'r': 2, 'n': 6, 's': -801, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 90
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -802, 'r': 2, 'n': 6, 's': -810, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 91
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -811, 'r': 2, 'n': 6, 's': -819, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 92
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -820, 'r': 2, 'n': 6, 's': -828, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 93
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -829, 'r': 2, 'n': 6, 's': -837, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 94
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -838, 'r': 2, 'n': 6, 's': -846, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 95
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -847, 'r': 2, 'n': 6, 's': -855, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 96
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -856, 'r': 2, 'n': 6, 's': -864, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 97
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -865, 'r': 2, 'n': 6, 's': -873, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 98
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -874, 'r': 2, 'n': 6, 's': -882, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========
# Iter: 99
# Best pair: ('e', 's')
# Tokens: defaultdict(<class 'int'>, {'l': 7, 'o': 7, 'w': 16, '</w>': 16, 'e': -883, 'r': 2, 'n': 6, 's': -891, 't': 9, 'i': 3, 'd': 3, 'es': 9})
# Number of tokens: 12
# ==========

# %% [markdown]
# After training, used the BPE dictionaries to tokenise sentences

# %%
def get_tokens_from_vocab(vocab):
    tokens_frequencies = collections.defaultdict(int)
    vocab_tokenization = {}
    for word, freq in vocab.items():
        word_tokens = word.split()
        for token in word_tokens:
            tokens_frequencies[token] += freq
        vocab_tokenization[''.join(word_tokens)] = word_tokens
    return tokens_frequencies, vocab_tokenization

def measure_token_length(token):
    if token[-4:] == '</w>':
        return len(token[:-4]) + 1
    else:
        return len(token)
    
def tokenize_word(string, sorted_tokens, unknown_token='</u>'):
    
    if string == '':
        return []
    if sorted_tokens == []:
        return [unknown_token] * len(string)

    string_tokens = []
    # iterate over all tokens to find match
    for i in range(len(sorted_tokens)):
        token = sorted_tokens[i]
        token_reg = re.escape(token.replace('.', '[.]'))
        matched_positions = [(m.start(0), m.end(0)) for m in re.finditer(token_reg, string)]
        # if no match found in the string, go to next token
        if len(matched_positions) == 0:
            continue
        # collect end position of matches in the string
        substring_end_positions = [matched_position[0] for matched_position in matched_positions]
        substring_start_position = 0
        for substring_end_position in substring_end_positions:
            # slice for sub-word
            substring = string[substring_start_position:substring_end_position]
            # tokenize this sub-word with tokens remaining
            string_tokens += tokenize_word(string=substring, sorted_tokens=sorted_tokens[i+1:], unknown_token=unknown_token)
            string_tokens += [token]
            substring_start_position = substring_end_position + len(token)
        # tokenize the remaining string
        remaining_substring = string[substring_start_position:]
        string_tokens += tokenize_word(string=remaining_substring, sorted_tokens=sorted_tokens[i+1:], unknown_token=unknown_token)
        break
    else:
        # return list of unknown token if no match is found for the string
        string_tokens = [unknown_token] * len(string)
        
    return string_tokens

"""
This function generates a list of all tokens sorted by their length (1st key) and frequency (2nd key).

EXAMPLE:
    token frequency dictionary before sorting: {'natural': 3, 'language':2, 'processing': 4, 'lecture': 4}
    sorted tokens: ['processing', 'language', 'lecture', 'natural']
    
INPUT:
    token_frequencies: Dict[str, int] # Counter for token frequency
    
OUTPUT:
    sorted_token: List[str] # Tokens sorted by length and frequency

"""
def sort_tokens(tokens_frequencies):
    ###
    # Your answer BEGINS HERE
    ###
    pass
    ###
    # Your answer ENDS HERE
    ###
    return sorted_tokens

#display the vocab
tokens_frequencies, vocab_tokenization = get_tokens_from_vocab(vocab)

#sort tokens by length and frequency
sorted_tokens = sort_tokens(tokens)
print("Tokens =", sorted_tokens, "\n")

sentence_1 = 'I like natural language processing!'
sentence_2 = 'I like natural languaaage processing!'
sentence_list = [sentence_1, sentence_2]

for sentence in sentence_list:
    
    print('==========')
    print("Sentence =", sentence)
    
    for word in sentence.split():
        word = word + "</w>"

        print('Tokenizing word: {}...'.format(word))
        if word in vocab_tokenization:
            print(vocab_tokenization[word])
        else:
            print(tokenize_word(string=word, sorted_tokens=sorted_tokens, unknown_token='</u>'))
# Out:
# Tokens = [('s', -891), ('e', -883), ('r', 2), ('i', 3), ('d', 3), ('n', 6), ('l', 7), ('o', 7), ('t', 9), ('w', 16), ('es', 9), ('</w>', 16)]
#
# ==========
# Sentence = I like natural language processing!
# Tokenizing word: I</w>...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b1a70cc81e31> in <module>
#      98             print(vocab_tokenization[word])
#      99         else:
# --> 100             print(tokenize_word(string=word, sorted_tokens=sorted_tokens, unknown_token='</u>'))
#
# <ipython-input-9-b1a70cc81e31> in tokenize_word(string, sorted_tokens, unknown_token)
#      26     for i in range(len(sorted_tokens)):
#      27         token = sorted_tokens[i]
# ---> 28         token_reg = re.escape(token.replace('.', '[.]'))
#      29         matched_positions = [(m.start(0), m.end(0)) for m in re.finditer(token_reg, string)]
#      30         # if no match found in the string, go to next token
#
# AttributeError: 'tuple' object has no attribute 'replace'
